# %% [markdown]
# # Physics AI Quickstart\n\nThis notebook uses the same SDK APIs as the CLI.

# %%
from physics_ai.theory import load_theory\nfrom physics_ai.symbolic import derive_field_equations\nfrom physics_ai.utils import generate_run_id\n\ntheory = load_theory('../examples/theories/einstein_hilbert.yaml')\nartifact = derive_field_equations(theory, run_id=generate_run_id('nb'))\nartifact
